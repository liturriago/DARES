# %%
# !git clone https://github.com/liturriago/DARES.git
# %cd /kaggle/working/DARES
# !pip install -e . -q
# Out:
# Cloning into 'DARES'...
# remote: Enumerating objects: 1047, done.
# remote: Counting objects: 100% (1047/1047), done.
# remote: Compressing objects: 100% (451/451), done.
# remote: Total 1047 (delta 698), reused 888 (delta 548), pack-reused 0 (from 0)
# Receiving objects: 100% (1047/1047), 15.61 MiB | 40.47 MiB/s, done.
# Resolving deltas: 100% (698/698), done.
# /kaggle/working/DARES
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
#   Building editable for dares (pyproject.toml) ... done

# %% [markdown]
# ### Source Only

# %%
# !python scripts/train.py\
--config configs/LIME_stress/high/source_only.yaml
# Out:
# Downloading: "https://download.pytorch.org/models/resnet50-0676ba61.pth" to /root/.cache/torch/hub/checkpoints/resnet50-0676ba61.pth
# 100%|███████████████████████████████████████| 97.8M/97.8M [00:00<00:00, 163MB/s]
#
#  Starting SOURCE_ONLY experiment on cuda...
# Warm-up enabled: backbone frozen for the first 2 epoch(s) (head-only training).
#
# Epoch 1/25
# ----------------------------------------
# [Train] Time: 00:29 | train_loss: 0.2113
# ...
# Source Val
# ...
# Class                    IoU      DICE      Prec    Recall   Support
# --------------------------------------------------------------------
# non_forest            0.8663    0.9284    0.9020    0.9562  26665560
# forest                0.8351    0.9102    0.9447    0.8781  22707624
# --------------------------------------------------------------------
# mean                  0.8507    0.9193
# ...
# Target Val
# ...
# Class                    IoU      DICE      Prec    Recall   Support
# ...

# %% [markdown]
# ### ADVENT

# %%
# !python scripts/train.py\
--config configs/LIME_stress/high/advent.yaml
# Out:
#  Starting ADVENT experiment on cuda...
# Warm-up enabled: backbone frozen for the first 2 epoch(s) (head-only training).
#
# Epoch 1/25
# ----------------------------------------
# Train (advent):   0%|                                   | 0/507 [00:00<?, ?it/s]/kaggle/working/DARES/src/dares/training/base_trainer.py:177: UserWarning: `parameters` is an empty generator, no gradient clipping will occur.
#   torch.nn.utils.clip_grad_norm_(params, float(clip))
# [Train] Time: 01:40 | loss_total: 0.3045 | loss_ce: 0.2153 | loss_adv: 0.6928 | loss_ent: 0.1991
# ...
# Source Val
# ...
# Class                    IoU      DICE      Prec    Recall   Support
# --------------------------------------------------------------------
# non_forest            0.7193    0.8367    0.7457    0.9530  26665560
# forest                0.5861    0.7390    0.9180    0.6184  22707624
# --------------------------------------------------------------------
# mean                  0.6527    0.7879
# ...
# Target Val
# ...

# %% [markdown]
# ### CBST

# %%
# !python scripts/train.py\
--config configs/LIME_stress/high/cbst.yaml
# Out:
#  Starting CBST experiment on cuda...
# Warm-up enabled: backbone frozen for the first 2 epoch(s) (head-only training).
#
# Epoch 1/25
# ----------------------------------------
# [Train] Time: 00:56 | loss_total: 0.2173 | loss_ce: 0.2147 | loss_self: 0.0026
# ...
# Source Val
# ...
# Class                    IoU      DICE      Prec    Recall   Support
# --------------------------------------------------------------------
# non_forest            0.6694    0.8019    0.9026    0.7215  26665560
# forest                0.6846    0.8128    0.7353    0.9085  22707624
# --------------------------------------------------------------------
# mean                  0.6770    0.8074
# ...
# Target Val
# ...
# Class                    IoU      DICE      Prec    Recall   Support
# --------------------------------------------------------------------
# non_forest            0.4776    0.6464    0.4954    0.9297  19126547
# forest                0.1300    0.2300    0.6836    0.1383  21014253
# ...

# %% [markdown]
# ### DARES

# %%
# !python scripts/train.py\
--config configs/LIME_stress/high/dares.yaml
# Out:
#  Starting DARES experiment on cuda...
# Warm-up enabled: backbone frozen for the first 2 epoch(s) (head-only training).
#
# Epoch 1/25
# ----------------------------------------
# [Train] Time: 00:31 | loss_total: 0.2113 | loss_seg: 0.2113 | loss_align: 0.0000 | loss_anti_collapse: 0.0000 | loss_repulsion: 0.0000 | loss_em: 0.0000
# ...
# Source Val
# ...
# Class                    IoU      DICE      Prec    Recall   Support
# --------------------------------------------------------------------
# non_forest            0.8661    0.9283    0.9016    0.9565  26665560
# forest                0.8348    0.9100    0.9450    0.8775  22707624
# --------------------------------------------------------------------
# mean                  0.8505    0.9191
# ...
# Target Val
# ...
# Class                    IoU      DICE      Prec    Recall   Support
# --------------------------------------------------------------------
# non_forest            0.4765    0.6454    0.4765    1.0000  19126547
# ...
