# %%
# !git clone https://github.com/liturriago/DARES.git
# %cd /kaggle/working/DARES
# !pip install -e . -q
# Out:
# Cloning into 'DARES'...
# remote: Enumerating objects: 1047, done.
# remote: Counting objects: 100% (1047/1047), done.
# remote: Compressing objects: 100% (451/451), done.
# remote: Total 1047 (delta 698), reused 888 (delta 548), pack-reused 0 (from 0)
# Receiving objects: 100% (1047/1047), 15.61 MiB | 34.16 MiB/s, done.
# Resolving deltas: 100% (698/698), done.
# /kaggle/working/DARES
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
#   Building editable for dares (pyproject.toml) ... done

# %% [markdown]
# ### DARES - No Align

# %%
# !python scripts/train.py\
--config configs/ablation/dares_no_align.yaml
# Out:
# Downloading: "https://download.pytorch.org/models/resnet50-0676ba61.pth" to /root/.cache/torch/hub/checkpoints/resnet50-0676ba61.pth
# 100%|███████████████████████████████████████| 97.8M/97.8M [00:00<00:00, 190MB/s]
#
#  Starting DARES experiment on cuda...
# Warm-up enabled: backbone frozen for the first 2 epoch(s) (head-only training).
#
# Epoch 1/25
# ----------------------------------------
# [Train] Time: 00:34 | loss_total: 0.2113 | loss_seg: 0.2113 | loss_align: 0.0000 | loss_anti_collapse: 0.0000 | loss_repulsion: 0.0000 | loss_em: 0.0000
# ...
# Source Val
# ...
# Class                    IoU      DICE      Prec    Recall   Support
# --------------------------------------------------------------------
# non_forest            0.8661    0.9282    0.9013    0.9568  26665560
# forest                0.8346    0.9099    0.9454    0.8769  22707624
# --------------------------------------------------------------------
# mean                  0.8504    0.9190
# ...
# Target Val
# ...

# %% [markdown]
# ### DARES - No Anticollapse

# %%
# !python scripts/train.py\
--config configs/ablation/dares_no_anti_collapse.yaml
# Out:
#  Starting DARES experiment on cuda...
# Warm-up enabled: backbone frozen for the first 2 epoch(s) (head-only training).
#
# Epoch 1/25
# ----------------------------------------
# [Train] Time: 00:34 | loss_total: 0.2113 | loss_seg: 0.2113 | loss_align: 0.0000 | loss_anti_collapse: 0.0000 | loss_repulsion: 0.0000 | loss_em: 0.0000
# ...
# Source Val
# ...
# Class                    IoU      DICE      Prec    Recall   Support
# --------------------------------------------------------------------
# non_forest            0.8661    0.9283    0.9016    0.9565  26665560
# forest                0.8348    0.9100    0.9450    0.8775  22707624
# --------------------------------------------------------------------
# mean                  0.8505    0.9191
# ...
# Target Val
# ...
# Class                    IoU      DICE      Prec    Recall   Support
# --------------------------------------------------------------------
# non_forest            0.4765    0.6454    0.4765    1.0000  19126547
# ...

# %% [markdown]
# ### DARES - No EM

# %%
# !python scripts/train.py\
--config configs/ablation/dares_no_em.yaml
# Out:
#  Starting DARES experiment on cuda...
# Warm-up enabled: backbone frozen for the first 2 epoch(s) (head-only training).
#
# Epoch 1/25
# ----------------------------------------
# [Train] Time: 00:34 | loss_total: 0.2113 | loss_seg: 0.2113 | loss_align: 0.0000 | loss_anti_collapse: 0.0000 | loss_repulsion: 0.0000 | loss_em: 0.0000
# ...
# Source Val
# ...
# Class                    IoU      DICE      Prec    Recall   Support
# --------------------------------------------------------------------
# non_forest            0.8660    0.9282    0.9021    0.9558  26665560
# forest                0.8349    0.9100    0.9442    0.8782  22707624
# --------------------------------------------------------------------
# mean                  0.8504    0.9191
# ...
# Target Val
# ...
# Class                    IoU      DICE      Prec    Recall   Support
# --------------------------------------------------------------------
# non_forest            0.4765    0.6454    0.4765    1.0000  19126547
# ...

# %% [markdown]
# ### DARES - No Repulsion

# %%
# !python scripts/train.py\
--config configs/ablation/dares_no_repulsion.yaml
# Out:
#  Starting DARES experiment on cuda...
# Warm-up enabled: backbone frozen for the first 2 epoch(s) (head-only training).
#
# Epoch 1/25
# ----------------------------------------
# [Train] Time: 00:34 | loss_total: 0.2113 | loss_seg: 0.2113 | loss_align: 0.0000 | loss_anti_collapse: 0.0000 | loss_repulsion: 0.0000 | loss_em: 0.0000
# ...
# Source Val
# ...
# Class                    IoU      DICE      Prec    Recall   Support
# --------------------------------------------------------------------
# non_forest            0.8662    0.9283    0.9014    0.9569  26665560
# forest                0.8348    0.9100    0.9455    0.8770  22707624
# --------------------------------------------------------------------
# mean                  0.8505    0.9191
# ...
# Target Val
# ...
# Class                    IoU      DICE      Prec    Recall   Support
# --------------------------------------------------------------------
# non_forest            0.4765    0.6454    0.4765    1.0000  19126547
# ...
