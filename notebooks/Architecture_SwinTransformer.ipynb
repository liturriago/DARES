# %%
# !git clone https://github.com/liturriago/DARES.git
# %cd /kaggle/working/DARES
# !pip install -e . -q
# Out:
# Cloning into 'DARES'...
# remote: Enumerating objects: 1226, done.
# remote: Counting objects: 100% (1226/1226), done.
# remote: Compressing objects: 100% (533/533), done.
# remote: Total 1226 (delta 825), reused 1034 (delta 642), pack-reused 0 (from 0)
# Receiving objects: 100% (1226/1226), 22.38 MiB | 27.45 MiB/s, done.
# Resolving deltas: 100% (825/825), done.
# /kaggle/working/DARES
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
#   Building editable for dares (pyproject.toml) ... done

# %% [markdown]
# ## SwinTransformer-DeepLabV3+

# %% [markdown]
# ### Source-Only

# %%
# !python scripts/train.py\
--config configs/architectures/swin_t_deeplabv3p/source_only.yaml
# Out:
# Downloading: "https://download.pytorch.org/models/swin_t-704ceda3.pth" to /root/.cache/torch/hub/checkpoints/swin_t-704ceda3.pth
# 100%|█████████████████████████████████████████| 108M/108M [00:00<00:00, 194MB/s]
#
#  Starting SOURCE_ONLY experiment on cuda...
# Warm-up enabled: backbone frozen for the first 2 epoch(s) (head-only training).
#
# Epoch 1/25
# ----------------------------------------
# [Train] Time: 00:43 | train_loss: 0.2276
# ...
# Source Val
# ...
# Class                    IoU      DICE      Prec    Recall   Support
# --------------------------------------------------------------------
# non_forest            0.8399    0.9130    0.8541    0.9807  26665560
# forest                0.7854    0.8798    0.9725    0.8033  22707624
# --------------------------------------------------------------------
# mean                  0.8127    0.8964
# ...
# Target Val
# ...
# Class                    IoU      DICE      Prec    Recall   Support
# ...

# %% [markdown]
# ### DARES

# %%
# !python scripts/train.py\
--config configs/architectures/swin_t_deeplabv3p/dares.yaml
# Out:
#  Starting DARES experiment on cuda...
# Warm-up enabled: backbone frozen for the first 2 epoch(s) (head-only training).
#
# Epoch 1/25
# ----------------------------------------
# [Train] Time: 00:45 | loss_total: 0.2275 | loss_seg: 0.2275 | loss_align: 0.0000 | loss_anti_collapse: 0.0000 | loss_repulsion: 0.0000 | loss_em: 0.0000
# ...
# Source Val
# ...
# Class                    IoU      DICE      Prec    Recall   Support
# --------------------------------------------------------------------
# non_forest            0.8398    0.9129    0.8537    0.9810  26665560
# forest                0.7851    0.8796    0.9730    0.8026  22707624
# --------------------------------------------------------------------
# mean                  0.8125    0.8963
# ...
# Target Val
# ...
# Class                    IoU      DICE      Prec    Recall   Support
# --------------------------------------------------------------------
# non_forest            0.4805    0.6491    0.4809    0.9985  19126547
# ...

# %% [markdown]
# ## SwinTransformer-ResUNet

# %% [markdown]
# ### Source-Only

# %%
# !python scripts/train.py\
--config configs/architectures/swin_t_resunet/source_only.yaml
# Out:
#  Starting SOURCE_ONLY experiment on cuda...
# Warm-up enabled: backbone frozen for the first 2 epoch(s) (head-only training).
#
# Epoch 1/25
# ----------------------------------------
# [Train] Time: 00:36 | train_loss: 0.1995
# ...
# Source Val
# ...
# Class                    IoU      DICE      Prec    Recall   Support
# --------------------------------------------------------------------
# non_forest            0.8505    0.9192    0.8587    0.9888  26665560
# forest                0.7985    0.8879    0.9841    0.8089  22707624
# --------------------------------------------------------------------
# mean                  0.8245    0.9036
# ...
# Target Val
# ...
# Class                    IoU      DICE      Prec    Recall   Support
# --------------------------------------------------------------------
# non_forest            0.4818    0.6503    0.4819    0.9998  19126547
# forest                0.0216    0.0423    0.9909    0.0216  21014253
# ...

# %% [markdown]
# ### DARES

# %%
# !python scripts/train.py\
--config configs/architectures/swin_t_resunet/dares.yaml
# Out:
#  Starting DARES experiment on cuda...
# Warm-up enabled: backbone frozen for the first 2 epoch(s) (head-only training).
#
# Epoch 1/25
# ----------------------------------------
# [Train] Time: 00:39 | loss_total: 0.1995 | loss_seg: 0.1995 | loss_align: 0.0000 | loss_anti_collapse: 0.0000 | loss_repulsion: 0.0000 | loss_em: 0.0000
# ...
# Source Val
# ...
# Class                    IoU      DICE      Prec    Recall   Support
# --------------------------------------------------------------------
# non_forest            0.8524    0.9203    0.8611    0.9883  26665560
# forest                0.8017    0.8900    0.9834    0.8128  22707624
# --------------------------------------------------------------------
# mean                  0.8271    0.9051
# ...
# Target Val
# ...
# Class                    IoU      DICE      Prec    Recall   Support
# --------------------------------------------------------------------
# non_forest            0.4819    0.6503    0.4819    0.9998  19126547
# ...
