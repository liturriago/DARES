# %%
# !git clone https://github.com/liturriago/DARES.git
# %cd /kaggle/working/DARES
# !pip install -e . -q
# Out:
# Cloning into 'DARES'...
# remote: Enumerating objects: 1226, done.
# remote: Counting objects: 100% (1226/1226), done.
# remote: Compressing objects: 100% (533/533), done.
# remote: Total 1226 (delta 825), reused 1034 (delta 642), pack-reused 0 (from 0)
# Receiving objects: 100% (1226/1226), 22.38 MiB | 50.15 MiB/s, done.
# Resolving deltas: 100% (825/825), done.
# /kaggle/working/DARES
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
#   Building editable for dares (pyproject.toml) ... done

# %% [markdown]
# ## ResNet-DeepLabV3+

# %% [markdown]
# ### Source-Only

# %%
# !python scripts/train.py\
--config configs/architectures/resnet50_deeplabv3p/source_only.yaml
# Out:
# Downloading: "https://download.pytorch.org/models/resnet50-0676ba61.pth" to /root/.cache/torch/hub/checkpoints/resnet50-0676ba61.pth
# 100%|███████████████████████████████████████| 97.8M/97.8M [00:00<00:00, 219MB/s]
#
#  Starting SOURCE_ONLY experiment on cuda...
# Warm-up enabled: backbone frozen for the first 2 epoch(s) (head-only training).
#
# Epoch 1/25
# ----------------------------------------
# [Train] Time: 00:36 | train_loss: 0.2218
# ...
# Source Val
# ...
# Class                    IoU      DICE      Prec    Recall   Support
# --------------------------------------------------------------------
# non_forest            0.8569    0.9230    0.9027    0.9442  26665560
# forest                0.8263    0.9049    0.9307    0.8805  22707624
# --------------------------------------------------------------------
# mean                  0.8416    0.9139
# ...
# Target Val
# ...
# Class                    IoU      DICE      Prec    Recall   Support
# ...

# %% [markdown]
# ### DARES

# %%
# !python scripts/train.py\
--config configs/architectures/resnet50_deeplabv3p/dares.yaml
# Out:
#  Starting DARES experiment on cuda...
# Warm-up enabled: backbone frozen for the first 2 epoch(s) (head-only training).
#
# Epoch 1/25
# ----------------------------------------
# [Train] Time: 00:37 | loss_total: 0.2217 | loss_seg: 0.2217 | loss_align: 0.0000 | loss_anti_collapse: 0.0000 | loss_repulsion: 0.0000 | loss_em: 0.0000
# ...
# Source Val
# ...
# Class                    IoU      DICE      Prec    Recall   Support
# --------------------------------------------------------------------
# non_forest            0.8569    0.9229    0.9026    0.9442  26665560
# forest                0.8262    0.9048    0.9307    0.8803  22707624
# --------------------------------------------------------------------
# mean                  0.8415    0.9139
# ...
# Target Val
# ...
# Class                    IoU      DICE      Prec    Recall   Support
# --------------------------------------------------------------------
# non_forest            0.4463    0.6171    0.6002    0.6351  19126547
# ...
