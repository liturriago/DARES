# %%
# !git clone https://github.com/liturriago/DARES.git
# %cd /kaggle/working/DARES
# !pip install -e . -q
# Out:
# Cloning into 'DARES'...
# remote: Enumerating objects: 1047, done.
# remote: Counting objects: 100% (1047/1047), done.
# remote: Compressing objects: 100% (451/451), done.
# remote: Total 1047 (delta 698), reused 888 (delta 548), pack-reused 0 (from 0)
# Receiving objects: 100% (1047/1047), 15.61 MiB | 29.17 MiB/s, done.
# Resolving deltas: 100% (698/698), done.
# /kaggle/working/DARES
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
#   Building editable for dares (pyproject.toml) ... done

# %% [markdown]
# ### Source Only

# %%
# !python scripts/train.py\
--config configs/LIME_stress/low/source_only.yaml
# Out:
# Downloading: "https://download.pytorch.org/models/resnet50-0676ba61.pth" to /root/.cache/torch/hub/checkpoints/resnet50-0676ba61.pth
# 100%|███████████████████████████████████████| 97.8M/97.8M [00:00<00:00, 186MB/s]
#
#  Starting SOURCE_ONLY experiment on cuda...
# Warm-up enabled: backbone frozen for the first 2 epoch(s) (head-only training).
#
# Epoch 1/25
# ----------------------------------------
# [Train] Time: 00:31 | train_loss: 0.2113
# ...
# Source Val
# ...
# Class                    IoU      DICE      Prec    Recall   Support
# --------------------------------------------------------------------
# non_forest            0.8662    0.9283    0.9024    0.9558  26665560
# forest                0.8352    0.9102    0.9443    0.8785  22707624
# --------------------------------------------------------------------
# mean                  0.8507    0.9193
# ...
# Target Val
# ...
# Class                    IoU      DICE      Prec    Recall   Support
# ...

# %% [markdown]
# ### ADVENT

# %%
# !python scripts/train.py\
--config configs/LIME_stress/low/advent.yaml
# Out:
#  Starting ADVENT experiment on cuda...
# Warm-up enabled: backbone frozen for the first 2 epoch(s) (head-only training).
#
# Epoch 1/25
# ----------------------------------------
# Train (advent):   0%|                                   | 0/507 [00:00<?, ?it/s]/kaggle/working/DARES/src/dares/training/base_trainer.py:177: UserWarning: `parameters` is an empty generator, no gradient clipping will occur.
#   torch.nn.utils.clip_grad_norm_(params, float(clip))
# [Train] Time: 01:41 | loss_total: 0.3051 | loss_ce: 0.2149 | loss_adv: 0.6963 | loss_ent: 0.2052
# ...
# Source Val
# ...
# Class                    IoU      DICE      Prec    Recall   Support
# --------------------------------------------------------------------
# non_forest            0.7847    0.8794    0.7875    0.9954  26665560
# forest                0.6810    0.8102    0.9922    0.6846  22707624
# --------------------------------------------------------------------
# mean                  0.7328    0.8448
# ...
# Target Val
# ...

# %% [markdown]
# ### CBST

# %%
# !python scripts/train.py\
--config configs/LIME_stress/low/cbst.yaml
# Out:
#  Starting CBST experiment on cuda...
# Warm-up enabled: backbone frozen for the first 2 epoch(s) (head-only training).
#
# Epoch 1/25
# ----------------------------------------
# [Train] Time: 00:57 | loss_total: 0.2192 | loss_ce: 0.2161 | loss_self: 0.0031
# ...
# Source Val
# ...
# Class                    IoU      DICE      Prec    Recall   Support
# --------------------------------------------------------------------
# non_forest            0.8139    0.8974    0.8228    0.9870  26665560
# forest                0.7390    0.8499    0.9800    0.7503  22707624
# --------------------------------------------------------------------
# mean                  0.7765    0.8737
# ...
# Target Val
# ...
# Class                    IoU      DICE      Prec    Recall   Support
# --------------------------------------------------------------------
# non_forest            0.7387    0.8497    0.9395    0.7755  19126547
# forest                0.7926    0.8843    0.8237    0.9546  21014253
# ...

# %% [markdown]
# ### DARES

# %%
# !python scripts/train.py\
--config configs/LIME_stress/low/dares.yaml
# Out:
#  Starting DARES experiment on cuda...
# Warm-up enabled: backbone frozen for the first 2 epoch(s) (head-only training).
#
# Epoch 1/25
# ----------------------------------------
# [Train] Time: 00:34 | loss_total: 0.2113 | loss_seg: 0.2113 | loss_align: 0.0000 | loss_anti_collapse: 0.0000 | loss_repulsion: 0.0000 | loss_em: 0.0000
# ...
# Source Val
# ...
# Class                    IoU      DICE      Prec    Recall   Support
# --------------------------------------------------------------------
# non_forest            0.8663    0.9284    0.9012    0.9572  26665560
# forest                0.8348    0.9100    0.9458    0.8768  22707624
# --------------------------------------------------------------------
# mean                  0.8506    0.9192
# ...
# Target Val
# ...
# Class                    IoU      DICE      Prec    Recall   Support
# --------------------------------------------------------------------
# non_forest            0.5087    0.6743    0.5770    0.8113  19126547
# ...
