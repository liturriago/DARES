# %%
# !git clone https://github.com/liturriago/DARES.git
# %cd /kaggle/working/DARES
# !pip install -e . -q
# Out:
# Cloning into 'DARES'...
# remote: Enumerating objects: 1226, done.
# remote: Counting objects: 100% (1226/1226), done.
# remote: Compressing objects: 100% (533/533), done.
# remote: Total 1226 (delta 825), reused 1034 (delta 642), pack-reused 0 (from 0)
# Receiving objects: 100% (1226/1226), 22.38 MiB | 25.41 MiB/s, done.
# Resolving deltas: 100% (825/825), done.
# /kaggle/working/DARES
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
#   Building editable for dares (pyproject.toml) ... done

# %%
# %cd /kaggle/working/DARES
# Out:
# /kaggle/working/DARES

# %% [markdown]
# ## ConvNeXt-DeepLabV3+

# %% [markdown]
# ### Source-Only

# %%
# !python scripts/train.py\
--config configs/architectures/convnext_tiny_deeplabv3p/source_only.yaml
# Out:
# Downloading: "https://download.pytorch.org/models/convnext_tiny-983f1562.pth" to /root/.cache/torch/hub/checkpoints/convnext_tiny-983f1562.pth
# 100%|█████████████████████████████████████████| 109M/109M [00:00<00:00, 241MB/s]
#
#  Starting SOURCE_ONLY experiment on cuda...
# Warm-up enabled: backbone frozen for the first 2 epoch(s) (head-only training).
#
# Epoch 1/25
# ----------------------------------------
# [Train] Time: 00:41 | train_loss: 0.2478
# ...
# Source Val
# ...
# Class                    IoU      DICE      Prec    Recall   Support
# --------------------------------------------------------------------
# non_forest            0.8540    0.9212    0.8924    0.9521  26665560
# forest                0.8190    0.9005    0.9389    0.8652  22707624
# --------------------------------------------------------------------
# mean                  0.8365    0.9109
# ...
# Target Val
# ...
# Class                    IoU      DICE      Prec    Recall   Support
# ...

# %% [markdown]
# ### DARES

# %%
# !python scripts/train.py\
--config configs/architectures/convnext_tiny_deeplabv3p/dares.yaml
# Out:
#  Starting DARES experiment on cuda...
# Warm-up enabled: backbone frozen for the first 2 epoch(s) (head-only training).
#
# Epoch 1/25
# ----------------------------------------
# [Train] Time: 00:46 | loss_total: 0.2556 | loss_seg: 0.2556 | loss_align: 0.0000 | loss_anti_collapse: 0.0000 | loss_repulsion: 0.0000 | loss_em: 0.0000
# ...
# Source Val
# ...
# Class                    IoU      DICE      Prec    Recall   Support
# --------------------------------------------------------------------
# non_forest            0.8529    0.9206    0.8961    0.9465  26665560
# forest                0.8196    0.9009    0.9327    0.8711  22707624
# --------------------------------------------------------------------
# mean                  0.8362    0.9107
# ...
# Target Val
# ...
# Class                    IoU      DICE      Prec    Recall   Support
# --------------------------------------------------------------------
# non_forest            0.4814    0.6499    0.4822    0.9964  19126547
# ...

# %% [markdown]
# ## ConvNeXt-ResUNet

# %% [markdown]
# ### Source-Only

# %%
# !python scripts/train.py\
--config configs/architectures/convnext_resunet/source_only.yaml
# Out:
#  Starting SOURCE_ONLY experiment on cuda...
# Warm-up enabled: backbone frozen for the first 2 epoch(s) (head-only training).
#
# Epoch 1/25
# ----------------------------------------
# [Train] Time: 00:36 | train_loss: 0.2103
# ...
# Source Val
# ...
# Class                    IoU      DICE      Prec    Recall   Support
# --------------------------------------------------------------------
# non_forest            0.8718    0.9315    0.9321    0.9309  26665560
# forest                0.8513    0.9197    0.9190    0.9204  22707624
# --------------------------------------------------------------------
# mean                  0.8616    0.9256
# ...
# Target Val
# ...
# Class                    IoU      DICE      Prec    Recall   Support
# --------------------------------------------------------------------
# non_forest            0.5194    0.6837    0.5238    0.9840  19126547
# forest                0.1831    0.3096    0.9272    0.1858  21014253
# ...

# %% [markdown]
# ### DARES

# %%
# !python scripts/train.py\
--config configs/architectures/convnext_resunet/dares.yaml
# Out:
#  Starting DARES experiment on cuda...
# Warm-up enabled: backbone frozen for the first 2 epoch(s) (head-only training).
#
# Epoch 1/25
# ----------------------------------------
# [Train] Time: 00:38 | loss_total: 0.2102 | loss_seg: 0.2102 | loss_align: 0.0000 | loss_anti_collapse: 0.0000 | loss_repulsion: 0.0000 | loss_em: 0.0000
# ...
# Source Val
# ...
# Class                    IoU      DICE      Prec    Recall   Support
# --------------------------------------------------------------------
# non_forest            0.8718    0.9315    0.9319    0.9312  26665560
# forest                0.8513    0.9197    0.9193    0.9200  22707624
# --------------------------------------------------------------------
# mean                  0.8616    0.9256
# ...
# Target Val
# ...
# Class                    IoU      DICE      Prec    Recall   Support
# --------------------------------------------------------------------
# non_forest            0.5197    0.6840    0.5239    0.9849  19126547
# ...
