# %%
# !git clone https://github.com/liturriago/DARES.git
# %cd /kaggle/working/DARES
# !pip install -e . -q
# Out:
# Cloning into 'DARES'...
# remote: Enumerating objects: 1047, done.
# remote: Counting objects: 100% (1047/1047), done.
# remote: Compressing objects: 100% (451/451), done.
# remote: Total 1047 (delta 698), reused 888 (delta 548), pack-reused 0 (from 0)
# Receiving objects: 100% (1047/1047), 15.61 MiB | 33.24 MiB/s, done.
# Resolving deltas: 100% (698/698), done.
# /kaggle/working/DARES
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
#   Building editable for dares (pyproject.toml) ... done

# %% [markdown]
# ### Source Only

# %%
# !python scripts/train.py\
--config configs/LIME_stress/medium/source_only.yaml
# Out:
# Downloading: "https://download.pytorch.org/models/resnet50-0676ba61.pth" to /root/.cache/torch/hub/checkpoints/resnet50-0676ba61.pth
# 100%|███████████████████████████████████████| 97.8M/97.8M [00:00<00:00, 178MB/s]
#
#  Starting SOURCE_ONLY experiment on cuda...
# Warm-up enabled: backbone frozen for the first 2 epoch(s) (head-only training).
#
# Epoch 1/25
# ----------------------------------------
# [Train] Time: 00:30 | train_loss: 0.2113
# ...
# Source Val
# ...
# Class                    IoU      DICE      Prec    Recall   Support
# --------------------------------------------------------------------
# non_forest            0.8661    0.9283    0.9015    0.9566  26665560
# forest                0.8348    0.9099    0.9451    0.8773  22707624
# --------------------------------------------------------------------
# mean                  0.8504    0.9191
# ...
# Target Val
# ...
# Class                    IoU      DICE      Prec    Recall   Support
# ...

# %% [markdown]
# ### ADVENT

# %%
# !python scripts/train.py\
--config configs/LIME_stress/medium/advent.yaml
# Out:
#  Starting ADVENT experiment on cuda...
# Warm-up enabled: backbone frozen for the first 2 epoch(s) (head-only training).
#
# Epoch 1/25
# ----------------------------------------
# Train (advent):   0%|                                   | 0/507 [00:00<?, ?it/s]/kaggle/working/DARES/src/dares/training/base_trainer.py:177: UserWarning: `parameters` is an empty generator, no gradient clipping will occur.
#   torch.nn.utils.clip_grad_norm_(params, float(clip))
# [Train] Time: 01:52 | loss_total: 0.3051 | loss_ce: 0.2154 | loss_adv: 0.6939 | loss_ent: 0.2030
# ...
# Source Val
# ...
# Class                    IoU      DICE      Prec    Recall   Support
# --------------------------------------------------------------------
# non_forest            0.6912    0.8174    0.6945    0.9930  26665560
# forest                0.4832    0.6515    0.9835    0.4871  22707624
# --------------------------------------------------------------------
# mean                  0.5872    0.7345
# ...
# Target Val
# ...

# %% [markdown]
# ### CBST

# %%
# !python scripts/train.py\
--config configs/LIME_stress/medium/cbst.yaml
# Out:
#  Starting CBST experiment on cuda...
# Warm-up enabled: backbone frozen for the first 2 epoch(s) (head-only training).
#
# Epoch 1/25
# ----------------------------------------
# [Train] Time: 01:00 | loss_total: 0.2181 | loss_ce: 0.2152 | loss_self: 0.0029
# ...
# Source Val
# ...
# Class                    IoU      DICE      Prec    Recall   Support
# --------------------------------------------------------------------
# non_forest            0.7568    0.8615    0.7736    0.9720  26665560
# forest                0.6448    0.7841    0.9529    0.6660  22707624
# --------------------------------------------------------------------
# mean                  0.7008    0.8228
# ...
# Target Val
# ...
# Class                    IoU      DICE      Prec    Recall   Support
# --------------------------------------------------------------------
# non_forest            0.5223    0.6862    0.5528    0.9045  19126547
# forest                0.3073    0.4702    0.7934    0.3341  21014253
# ...

# %% [markdown]
# ### DARES

# %%
# !python scripts/train.py\
--config configs/LIME_stress/medium/dares.yaml
# Out:
#  Starting DARES experiment on cuda...
# Warm-up enabled: backbone frozen for the first 2 epoch(s) (head-only training).
#
# Epoch 1/25
# ----------------------------------------
# [Train] Time: 00:33 | loss_total: 0.2113 | loss_seg: 0.2113 | loss_align: 0.0000 | loss_anti_collapse: 0.0000 | loss_repulsion: 0.0000 | loss_em: 0.0000
# ...
# Source Val
# ...
# Class                    IoU      DICE      Prec    Recall   Support
# --------------------------------------------------------------------
# non_forest            0.8662    0.9283    0.9013    0.9569  26665560
# forest                0.8347    0.9099    0.9455    0.8769  22707624
# --------------------------------------------------------------------
# mean                  0.8504    0.9191
# ...
# Target Val
# ...
# Class                    IoU      DICE      Prec    Recall   Support
# --------------------------------------------------------------------
# non_forest            0.4765    0.6454    0.4765    1.0000  19126547
# ...
